# %%
import pandas as pd
d=pd.read_csv('/content/drive/MyDrive/Data_for_UCI_named (1).csv')

# %%
print(d)
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4      stab  stabf
# 0    -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347      0
# 1    -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957      1
# 2    -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471      0
# 3    -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871      0
# 4    -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860      0
# ...        ...       ...       ...       ...       ...       ...    ...
# 9995 -1.236256  0.601709  0.779642  0.813512  0.608385  0.023892      0
# 9996 -1.733414  0.502079  0.567242  0.285880  0.366120 -0.025803      1
# 9997 -1.975373  0.487838  0.986505  0.149286  0.145984 -0.031810      1
# 9998 -0.898510  0.365246  0.587558  0.889118  0.818391  0.037789      0
# 9999 -0.570329  0.073056  0.505441  0.378761  0.942631  0.045263      0
#
# [10000 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
x=d['stab']
y=d['stabf']

# %%
plt.plot(x,y)

# %%
corr_matrix=d.corr()
print(corr_matrix)
# Out:
#            tau1      tau2      tau3      tau4        p1        p2        p3  \
# tau1   1.000000  0.015586 -0.005970 -0.017265  0.027183 -0.015485 -0.015924
# tau2   0.015586  1.000000  0.014273 -0.001965 -0.004769  0.006573  0.007673
# tau3  -0.005970  0.014273  1.000000  0.004354  0.016953 -0.003134 -0.008780
# tau4  -0.017265 -0.001965  0.004354  1.000000 -0.003173  0.010553  0.006169
# p1     0.027183 -0.004769  0.016953 -0.003173  1.000000 -0.573157 -0.584554
# p2    -0.015485  0.006573 -0.003134  0.010553 -0.573157  1.000000  0.002388
# p3    -0.015924  0.007673 -0.008780  0.006169 -0.584554  0.002388  1.000000
# p4    -0.015807 -0.005963 -0.017531 -0.011211 -0.579239 -0.006844  0.012953
# g1     0.010521 -0.001742 -0.011605 -0.004149  0.000721  0.015603 -0.003219
# g2     0.015350  0.015383  0.007671  0.008431  0.015405 -0.018032 -0.011575
# g3    -0.001279  0.016508  0.014702  0.003260  0.001069  0.007555 -0.005897
# g4     0.005494 -0.011764 -0.011497 -0.000491 -0.015451  0.019817 -0.010485
# stab   0.275761  0.290975  0.280700  0.278576  0.010278  0.006255 -0.003321
# stabf -0.234898 -0.246280 -0.237492 -0.239375 -0.009938 -0.006173  0.000649
#
#              p4        g1        g2        g3        g4      stab     stabf
# tau1  -0.015807  0.010521  0.015350 -0.001279  0.005494  0.275761 -0.234898
# tau2  -0.005963 -0.001742  0.015383  0.016508 -0.011764  0.290975 -0.246280
# tau3  -0.017531 -0.011605  0.007671  0.014702 -0.011497  0.280700 -0.237492
# tau4  -0.011211 -0.004149  0.008431  0.003260 -0.000491  0.278576 -0.239375
# p1    -0.579239  0.000721  0.015405  0.001069 -0.015451  0.010278 -0.009938
# p2    -0.006844  0.015603 -0.018032  0.007555  0.019817  0.006255 -0.006173
# p3     0.012953 -0.003219 -0.011575 -0.005897 -0.010485 -0.003321  0.000649
# p4     1.000000 -0.013636  0.002850 -0.003515  0.017505 -0.020786  0.022785
# g1    -0.013636  1.000000  0.007559 -0.005836  0.012431  0.282774 -0.197664
# g2     0.002850  0.007559  1.000000 -0.012809 -0.014909  0.293601 -0.217341
# g3    -0.003515 -0.005836 -0.012809  1.000000  0.006900  0.308235 -0.231774
# g4     0.017505  0.012431 -0.014909  0.006900  1.000000  0.279214 -0.204931
# stab  -0.020786  0.282774  0.293601  0.308235  0.279214  1.000000 -0.826959
# stabf  0.022785 -0.197664 -0.217341 -0.231774 -0.204931 -0.826959  1.000000

# %%
import seaborn as sn
import matplotlib.pyplot as plt
sn.heatmap(corr_matrix,annot=True)
# Out:
# <Axes: >

# %%
cov_matrix=d.cov()
print(cov_matrix)
# Out:
#            tau1      tau2      tau3      tau4        p1        p2        p3  \
# tau1   7.521572  0.117229 -0.044901 -0.129862  0.056075 -0.018391 -0.018911
# tau2   0.117229  7.521573  0.107359 -0.014778 -0.009838  0.007807  0.009112
# tau3  -0.044901  0.107359  7.521578  0.032752  0.034970 -0.003722 -0.010428
# tau4  -0.129862 -0.014778  0.032752  7.521611 -0.006545  0.012533  0.007326
# p1     0.056075 -0.009838  0.034970 -0.006545  0.565745 -0.186684 -0.190396
# p2    -0.018391  0.007807 -0.003722  0.012533 -0.186684  0.187519  0.000448
# p3    -0.018911  0.009112 -0.010428  0.007326 -0.190396  0.000448  0.187519
# p4    -0.018773 -0.007081 -0.020820 -0.013315 -0.188665 -0.001283  0.002429
# g1     0.007914 -0.001311 -0.008729 -0.003121  0.000149  0.001853 -0.000382
# g2     0.011545  0.011571  0.005770  0.006342  0.003178 -0.002142 -0.001375
# g3    -0.000962  0.012417  0.011058  0.002452  0.000221  0.000897 -0.000700
# g4     0.004132 -0.008848 -0.008648 -0.000369 -0.003187  0.002354 -0.001245
# stab   0.027921  0.029462  0.028421  0.028207  0.000285  0.000100 -0.000053
# stabf -0.309614 -0.324616 -0.313032 -0.315515 -0.003592 -0.001285  0.000135
#
#              p4        g1        g2        g3        g4      stab     stabf
# tau1  -0.018773  0.007914  0.011545 -0.000962  0.004132  0.027921 -0.309614
# tau2  -0.007081 -0.001311  0.011571  0.012417 -0.008848  0.029462 -0.324616
# tau3  -0.020820 -0.008729  0.005770  0.011058 -0.008648  0.028421 -0.313032
# tau4  -0.013315 -0.003121  0.006342  0.002452 -0.000369  0.028207 -0.315515
# p1    -0.188665  0.000149  0.003178  0.000221 -0.003187  0.000285 -0.003592
# p2    -0.001283  0.001853 -0.002142  0.000897  0.002354  0.000100 -0.001285
# p3     0.002429 -0.000382 -0.001375 -0.000700 -0.001245 -0.000053  0.000135
# p4     0.187519 -0.001619  0.000338 -0.000417  0.002079 -0.000332  0.004742
# g1    -0.001619  0.075216  0.000569 -0.000439  0.000935  0.002863 -0.026054
# g2     0.000338  0.000569  0.075216 -0.000963 -0.001121  0.002973 -0.028647
# g3    -0.000417 -0.000439 -0.000963  0.075216  0.000519  0.003121 -0.030550
# g4     0.002079  0.000935 -0.001121  0.000519  0.075216  0.002827 -0.027011
# stab  -0.000332  0.002863  0.002973  0.003121  0.002827  0.001363 -0.014673
# stabf  0.004742 -0.026054 -0.028647 -0.030550 -0.027011 -0.014673  0.230979

# %%
import seaborn as sn
import matplotlib.pyplot as plt
sn.heatmap(cov_matrix,annot=True)
# Out:
# <Axes: >

# %%
x=d.iloc[:,0:13]
y=d.iloc[:,13:14]
print(x)
print(y)
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4      stab
# 0    -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347
# 1    -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957
# 2    -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471
# 3    -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871
# 4    -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860
# ...        ...       ...       ...       ...       ...       ...
# 9995 -1.236256  0.601709  0.779642  0.813512  0.608385  0.023892
# 9996 -1.733414  0.502079  0.567242  0.285880  0.366120 -0.025803
# 9997 -1.975373  0.487838  0.986505  0.149286  0.145984 -0.031810
# 9998 -0.898510  0.365246  0.587558  0.889118  0.818391  0.037789
# 9999 -0.570329  0.073056  0.505441  0.378761  0.942631  0.045263
#
# [10000 rows x 13 columns]
#       stabf
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
# ...     ...
# 9995      0
# 9996      1
# 9997      1
# 9998      0
# 9999      0
#
# [10000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
print(x.shape)
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=True,test_size=0.20)
# Out:
# (10000, 13)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
mm=lr.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
yp=mm.predict(x_test)

# %%
print(yp)
# Out:
# [0 0 1 ... 1 0 0]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(yp,y_test))
# Out:
# 0.881

# %%
from sklearn import metrics

# %%
confusion_matrix=metrics.confusion_matrix(y_test,yp)

# %%
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=[0,1])

# %%
import matplotlib.pyplot as plt

# %%
cm_display.plot()
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier=KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)
classifier.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
yp=classifier.predict(x_test)

# %%
print(yp)
# Out:
# [0 0 0 ... 1 0 0]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(yp,y_test))
# Out:
# 0.794

# %%
from sklearn import metrics

# %%
confusion_matrix=metrics.confusion_matrix(y_test,yp)

# %%
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=[0,1])

# %%
import matplotlib.pyplot as plt

# %%
cm_display.plot()
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
yp=gnb.predict(x_test)

# %%
print(yp)
# Out:
# [0 0 1 ... 1 0 0]

# %%
accuracy=accuracy_score(yp,y_test)

# %%
print(accuracy)
# Out:
# 0.974

# %%
from sklearn import metrics

# %%
confusion_matrix=metrics.confusion_matrix(y_test,yp)

# %%
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=[0,1])

# %%
import matplotlib.pyplot as plt

# %%
cm_display.plot()
plt.show()

# %%
from sklearn.svm import SVC

# %%
svm_model=SVC(kernel='linear')

# %%
svm_model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='linear')

# %%
yp=svm_model.predict(x_test)

# %%
print(yp)
# Out:
# [0 0 1 ... 1 0 0]

# %%
accuracy=accuracy_score(yp,y_test)

# %%
print(accuracy)
# Out:
# 0.9335

# %%
from sklearn import metrics

# %%
confusion_matrix=metrics.confusion_matrix(y_test,yp)

# %%
cm_display=metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix,display_labels=[0,1])

# %%
import matplotlib.pyplot as plt

# %%
cm_display.plot()
plt.show()
